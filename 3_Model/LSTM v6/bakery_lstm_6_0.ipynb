# %%
'''

based on the 5.0 version

'''

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.metrics import MeanAbsolutePercentageError
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt

# Load data
kiwo_url = '../../Data/kiwo.csv'
umsatz_url = '../../Data/train.csv'
wetter_url = '../../Data/wetter.csv'
test_url = '../../Data/test.csv'

df_kiwo = pd.read_csv(kiwo_url)
df_umsatz = pd.read_csv(umsatz_url)
df_wetter = pd.read_csv(wetter_url)
df_test = pd.read_csv(test_url)

# Merge data
df_train = pd.merge(df_umsatz, df_wetter, on='Datum', how='left')
df_train = pd.merge(df_train, df_kiwo, on='Datum', how='left')
df_test = pd.merge(df_test, df_wetter, on='Datum', how='left')
df_test = pd.merge(df_test, df_kiwo, on='Datum', how='left')

# Function to prepare data
def prepare_data(data):
    data['Datum'] = pd.to_datetime(data['Datum'])
    data['DayOfWeek'] = data['Datum'].dt.dayofweek
    data['Month'] = data['Datum'].dt.month
    data['IsWeekend'] = (data['DayOfWeek'] >= 5).astype(float)
    data['KielerWoche'] = data['KielerWoche'].fillna(0).astype(float)
    
    # Replace NaNs using KNN Imputer
    numerical_cols = ['Temperatur', 'Windgeschwindigkeit', 'Bewoelkung', 'Wettercode', 'IsWeekend']
    knn_imputer = KNNImputer(n_neighbors=5)
    data[numerical_cols] = knn_imputer.fit_transform(data[numerical_cols])
    
    # One-hot encode categorical features
    warengruppe_dummies = pd.get_dummies(data['Warengruppe'], prefix='Warengruppe')
    day_dummies = pd.get_dummies(data['DayOfWeek'], prefix='Day')
    month_dummies = pd.get_dummies(data['Month'], prefix='Month')
    
    # Combine all features
    feature_df = pd.concat([data[numerical_cols], warengruppe_dummies, day_dummies, month_dummies], axis=1)
    return feature_df

# Prepare datasets
df_train_sorted = df_train.sort_values(by='Datum')
X_train = prepare_data(df_train_sorted)
y_train = df_train_sorted['Umsatz']
X_test = prepare_data(df_test)

print(X_train.head())

# Standardize data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# should be split on DATE? 
# Split data into training and validation sets
split_index = int(len(X_train) * 0.8)
X_train_seq, X_val_seq = X_train[:split_index], X_train[split_index:]
y_train_seq, y_val_seq = y_train[:split_index], y_train[split_index:]

# Reshape for LSTM (samples, time steps, features)
X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], 1, X_train_seq.shape[1])
X_val_seq = X_val_seq.reshape(X_val_seq.shape[0], 1, X_val_seq.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# Learning rate scheduler function
def lr_schedule(epoch, lr):
    initial_lr = 0.01  # Start with this learning rate
    decay_rate = 0.1  # Decay rate
    decay_steps = 10  # Epochs after which to decay
    return initial_lr * np.exp(-decay_rate * (epoch / decay_steps))

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

# Build the model 
model = tf.keras.Sequential([
    LSTM(64, activation='relu', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])), # default 50
    Dropout(0.2), # default 0.2
    Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse', metrics=['mean_absolute_percentage_error'])

# Train the model
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=150, # was 150
    batch_size=32, 
    validation_data=(X_val_seq, y_val_seq), 
    callbacks=[early_stopping, model_checkpoint, lr_scheduler]
)

# Calculate predictions for validation set
val_predictions = model.predict(X_val_seq).flatten()

# Get original Warengruppe values for validation set
val_warengruppen = df_train_sorted.iloc[split_index:]['Warengruppe']

# Create DataFrame with actual and predicted values
results_df = pd.DataFrame({
    'Warengruppe': val_warengruppen,
    'Actual': y_val_seq,
    'Predicted': val_predictions
})

# Calculate MAPE for each Warengruppe
mape_by_group = results_df.groupby('Warengruppe').apply(
    lambda x: MeanAbsolutePercentageError()(x['Actual'], x['Predicted']).numpy()
).sort_values()

print("\nMAPE by Warengruppe:")

# save the MAPEs of each warengruppe in a dict
warengruppe_MAPE_dict = {}
for warengruppe, mape in mape_by_group.items():
    print(f"Warengruppe {warengruppe}: {mape:.2f}%")
    warengruppe_MAPE_dict[warengruppe] = mape

fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the training and validation loss on the primary y-axis
ax1.plot(history.history['loss'], label='Train Loss', color='blue')
ax1.plot(history.history['val_loss'], label='Val Loss', color='darkblue')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')

# Determine the minimum and maximum loss values to set the y-axis limits
min_loss = min(min(history.history['loss']), min(history.history['val_loss']))
max_loss = max(max(history.history['loss']), max(history.history['val_loss']))
ax1.set_ylim(min_loss * 0.9, max_loss * 1.1)  # Add some padding
ax1.tick_params(axis='y', labelcolor='black')

# Create a twin y-axis for the MAPE
ax2 = ax1.twinx()

# Plot the training and validation MAPE on the twin y-axis
ax2.plot(history.history['mean_absolute_percentage_error'], label='Train MAPE', color='orange')
ax2.plot(history.history['val_mean_absolute_percentage_error'], label='Val MAPE', color='red')
ax2.set_ylabel('MAPE (%)', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Set the y-axis limits for the MAPE to 0-100%
ax2.set_ylim(0, 100)

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# Load the best model
model.load_weights('best_model.keras')

# Evaluate on validation set
val_predictions = model.predict(X_val_seq).flatten()
val_mape = tf.keras.metrics.MeanAbsolutePercentageError()(y_val_seq, val_predictions).numpy()
print(f'MAPE on validation set: {val_mape:.2f}%')

# Make predictions on test set and save results
test_predictions = model.predict(X_test).flatten()
df_test['Predicted_Umsatz'] = test_predictions
df_test.to_csv('predicted_test.csv', index=False)
# Out:
# 2025-01-08 21:46:10.426075: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-08 21:46:10.439031: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-08 21:46:10.644110: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-08 21:46:10.744599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736372771.018377    9652 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736372771.107973    9652 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 21:46:11.684658: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#       Temperatur  Windgeschwindigkeit  Bewoelkung  Wettercode  IsWeekend  \
# 0        17.8375                 15.0         6.0        20.0        0.0
# 3638     17.8375                 15.0         6.0        20.0        0.0
# 7223     17.8375                 15.0         6.0        20.0        0.0
# 1819     17.8375                 15.0         6.0        20.0        0.0
# 5457     17.8375                 15.0         6.0        20.0        0.0
#
#       Warengruppe_1  Warengruppe_2  Warengruppe_3  Warengruppe_4  \
# 0              True          False          False          False
# 3638          False          False           True          False
# 7223          False          False          False          False
# 1819          False           True          False          False
# 5457          False          False          False           True
#
#       Warengruppe_5  ...  Month_3  Month_4  Month_5  Month_6  Month_7  \
# 0             False  ...    False    False    False    False     True
# 3638          False  ...    False    False    False    False     True
# 7223           True  ...    False    False    False    False     True
# 1819          False  ...    False    False    False    False     True
# 5457          False  ...    False    False    False    False     True
#
#       Month_8  Month_9  Month_10  Month_11  Month_12
# 0       False    False     False     False     False
# 3638    False    False     False     False     False
# 7223    False    False     False     False     False
# 1819    False    False     False     False     False
# 5457    False    False     False     False     False
#
# [5 rows x 30 columns]
# Epoch 1/150
# 2025-01-08 21:46:17.339168: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 41195.2617 - mean_absolute_percentage_error: 74.7351 - val_loss: 3499.4382 - val_mean_absolute_percentage_error: 24.3106 - learning_rate: 0.0100
# Epoch 2/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3809.6528 - mean_absolute_percentage_error: 24.5994 - val_loss: 3253.6665 - val_mean_absolute_percentage_error: 22.4299 - learning_rate: 0.0099
# Epoch 3/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4176.2100 - mean_absolute_percentage_error: 22.7517 - val_loss: 3319.1235 - val_mean_absolute_percentage_error: 21.9440 - learning_rate: 0.0098
# Epoch 4/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3607.0247 - mean_absolute_percentage_error: 21.2885 - val_loss: 3121.0051 - val_mean_absolute_percentage_error: 21.1107 - learning_rate: 0.0097
# Epoch 5/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4047.3521 - mean_absolute_percentage_error: 21.2438 - val_loss: 3203.3269 - val_mean_absolute_percentage_error: 21.9724 - learning_rate: 0.0096
# Epoch 6/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3843.1978 - mean_absolute_percentage_error: 21.2802 - val_loss: 3239.6274 - val_mean_absolute_percentage_error: 22.9303 - learning_rate: 0.0095
# Epoch 7/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4997.9683 - mean_absolute_percentage_error: 21.5781 - val_loss: 3243.2920 - val_mean_absolute_percentage_error: 22.0362 - learning_rate: 0.0094
# Epoch 8/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3323.5486 - mean_absolute_percentage_error: 20.8016 - val_loss: 3245.1660 - val_mean_absolute_percentage_error: 22.1828 - learning_rate: 0.0093
# Epoch 9/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4355.6543 - mean_absolute_percentage_error: 21.1406 - val_loss: 3289.9832 - val_mean_absolute_percentage_error: 22.3552 - learning_rate: 0.0092
# Epoch 10/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3655.1812 - mean_absolute_percentage_error: 21.2584 - val_loss: 3733.0771 - val_mean_absolute_percentage_error: 23.2134 - learning_rate: 0.0091
# Epoch 11/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3785.2129 - mean_absolute_percentage_error: 20.8087 - val_loss: 3305.6655 - val_mean_absolute_percentage_error: 22.5177 - learning_rate: 0.0090
# Epoch 12/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4547.5938 - mean_absolute_percentage_error: 20.8309 - val_loss: 3269.7356 - val_mean_absolute_percentage_error: 22.0065 - learning_rate: 0.0090
# Epoch 13/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3206.0061 - mean_absolute_percentage_error: 20.6746 - val_loss: 3423.5544 - val_mean_absolute_percentage_error: 22.9516 - learning_rate: 0.0089
# Epoch 14/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4288.3247 - mean_absolute_percentage_error: 20.6366 - val_loss: 3191.0051 - val_mean_absolute_percentage_error: 21.3926 - learning_rate: 0.0088
# Epoch 15/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3354.3494 - mean_absolute_percentage_error: 20.5949 - val_loss: 3257.4531 - val_mean_absolute_percentage_error: 21.7554 - learning_rate: 0.0087
# Epoch 16/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3671.8809 - mean_absolute_percentage_error: 20.3400 - val_loss: 3209.0654 - val_mean_absolute_percentage_error: 21.0858 - learning_rate: 0.0086
# Epoch 17/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3555.6482 - mean_absolute_percentage_error: 20.2180 - val_loss: 3435.7156 - val_mean_absolute_percentage_error: 22.5155 - learning_rate: 0.0085
# Epoch 18/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5038.5161 - mean_absolute_percentage_error: 20.0330 - val_loss: 3036.8333 - val_mean_absolute_percentage_error: 20.5098 - learning_rate: 0.0084
# Epoch 19/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3896.6460 - mean_absolute_percentage_error: 20.1883 - val_loss: 3157.5715 - val_mean_absolute_percentage_error: 21.0485 - learning_rate: 0.0084
# Epoch 20/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4175.1030 - mean_absolute_percentage_error: 20.3197 - val_loss: 3191.2354 - val_mean_absolute_percentage_error: 21.2075 - learning_rate: 0.0083
# Epoch 21/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4607.4121 - mean_absolute_percentage_error: 19.7514 - val_loss: 3424.8789 - val_mean_absolute_percentage_error: 21.9482 - learning_rate: 0.0082
# Epoch 22/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3081.5342 - mean_absolute_percentage_error: 19.9868 - val_loss: 3429.2476 - val_mean_absolute_percentage_error: 22.3966 - learning_rate: 0.0081
# Epoch 23/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3432.9438 - mean_absolute_percentage_error: 19.7713 - val_loss: 3453.2400 - val_mean_absolute_percentage_error: 21.8869 - learning_rate: 0.0080
# Epoch 24/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3341.1343 - mean_absolute_percentage_error: 19.7464 - val_loss: 3267.4719 - val_mean_absolute_percentage_error: 21.1957 - learning_rate: 0.0079
# Epoch 25/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3532.0063 - mean_absolute_percentage_error: 19.8065 - val_loss: 3413.8977 - val_mean_absolute_percentage_error: 22.2714 - learning_rate: 0.0079
# Epoch 26/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4061.9111 - mean_absolute_percentage_error: 19.9729 - val_loss: 3226.4272 - val_mean_absolute_percentage_error: 21.3092 - learning_rate: 0.0078
# Epoch 27/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2956.5959 - mean_absolute_percentage_error: 20.1395 - val_loss: 3611.4028 - val_mean_absolute_percentage_error: 23.1779 - learning_rate: 0.0077
# Epoch 28/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4576.1470 - mean_absolute_percentage_error: 19.9200 - val_loss: 3445.8049 - val_mean_absolute_percentage_error: 22.1470 - learning_rate: 0.0076
# Epoch 29/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3656.1343 - mean_absolute_percentage_error: 19.4214 - val_loss: 3543.4424 - val_mean_absolute_percentage_error: 22.0166 - learning_rate: 0.0076
# Epoch 30/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3052.4626 - mean_absolute_percentage_error: 19.5556 - val_loss: 3870.0847 - val_mean_absolute_percentage_error: 23.9498 - learning_rate: 0.0075
# Epoch 31/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3884.3840 - mean_absolute_percentage_error: 19.3459 - val_loss: 3423.0100 - val_mean_absolute_percentage_error: 21.8666 - learning_rate: 0.0074
# Epoch 32/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2862.0256 - mean_absolute_percentage_error: 19.2992 - val_loss: 3480.8113 - val_mean_absolute_percentage_error: 21.9765 - learning_rate: 0.0073
# Epoch 33/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3012.0364 - mean_absolute_percentage_error: 19.1517 - val_loss: 3758.8257 - val_mean_absolute_percentage_error: 23.3125 - learning_rate: 0.0073
# Epoch 34/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2695.7568 - mean_absolute_percentage_error: 19.0543 - val_loss: 3582.4702 - val_mean_absolute_percentage_error: 22.5575 - learning_rate: 0.0072
# Epoch 35/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2628.3950 - mean_absolute_percentage_error: 19.0322 - val_loss: 3716.4773 - val_mean_absolute_percentage_error: 23.0879 - learning_rate: 0.0071
# Epoch 36/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3093.2280 - mean_absolute_percentage_error: 19.3275 - val_loss: 3401.2292 - val_mean_absolute_percentage_error: 22.0315 - learning_rate: 0.0070
# Epoch 37/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3313.8386 - mean_absolute_percentage_error: 19.0517 - val_loss: 3663.7634 - val_mean_absolute_percentage_error: 22.6064 - learning_rate: 0.0070
# Epoch 38/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3517.0083 - mean_absolute_percentage_error: 18.7219 - val_loss: 3586.3042 - val_mean_absolute_percentage_error: 23.2944 - learning_rate: 0.0069
# Epoch 39/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2468.2312 - mean_absolute_percentage_error: 18.5744 - val_loss: 3804.3870 - val_mean_absolute_percentage_error: 23.5844 - learning_rate: 0.0068
# Epoch 40/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2752.4312 - mean_absolute_percentage_error: 19.3022 - val_loss: 3636.4595 - val_mean_absolute_percentage_error: 22.5454 - learning_rate: 0.0068
# Epoch 41/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2450.0923 - mean_absolute_percentage_error: 18.8885 - val_loss: 4041.9856 - val_mean_absolute_percentage_error: 24.6025 - learning_rate: 0.0067
# Epoch 42/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3461.6824 - mean_absolute_percentage_error: 19.2619 - val_loss: 3813.7976 - val_mean_absolute_percentage_error: 23.5354 - learning_rate: 0.0066
# Epoch 43/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3225.2505 - mean_absolute_percentage_error: 19.0812 - val_loss: 3611.5718 - val_mean_absolute_percentage_error: 22.4804 - learning_rate: 0.0066
# Epoch 44/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2691.5088 - mean_absolute_percentage_error: 19.0203 - val_loss: 3620.8169 - val_mean_absolute_percentage_error: 22.9033 - learning_rate: 0.0065
# Epoch 45/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2951.8936 - mean_absolute_percentage_error: 18.7963 - val_loss: 3689.3889 - val_mean_absolute_percentage_error: 23.0461 - learning_rate: 0.0064
# Epoch 46/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2975.0627 - mean_absolute_percentage_error: 18.7268 - val_loss: 3687.9116 - val_mean_absolute_percentage_error: 22.4896 - learning_rate: 0.0064
# Epoch 47/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2893.0061 - mean_absolute_percentage_error: 18.6042 - val_loss: 3696.6917 - val_mean_absolute_percentage_error: 22.9325 - learning_rate: 0.0063
# Epoch 48/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3120.3555 - mean_absolute_percentage_error: 19.1116 - val_loss: 3665.0090 - val_mean_absolute_percentage_error: 22.9941 - learning_rate: 0.0063
# Epoch 49/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2406.0024 - mean_absolute_percentage_error: 18.6689 - val_loss: 3866.3892 - val_mean_absolute_percentage_error: 23.6491 - learning_rate: 0.0062
# Epoch 50/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2728.8555 - mean_absolute_percentage_error: 18.5548 - val_loss: 3743.5029 - val_mean_absolute_percentage_error: 23.4496 - learning_rate: 0.0061
# Epoch 51/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3319.2119 - mean_absolute_percentage_error: 19.6132 - val_loss: 3557.9758 - val_mean_absolute_percentage_error: 22.5026 - learning_rate: 0.0061
# Epoch 52/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2501.2053 - mean_absolute_percentage_error: 18.8449 - val_loss: 3845.9719 - val_mean_absolute_percentage_error: 23.8495 - learning_rate: 0.0060
# Epoch 53/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2492.0325 - mean_absolute_percentage_error: 19.0662 - val_loss: 4125.0415 - val_mean_absolute_percentage_error: 24.5250 - learning_rate: 0.0059
# Epoch 54/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2886.7371 - mean_absolute_percentage_error: 18.3542 - val_loss: 3637.2959 - val_mean_absolute_percentage_error: 22.7542 - learning_rate: 0.0059
# Epoch 55/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2642.4753 - mean_absolute_percentage_error: 18.6676 - val_loss: 3874.9119 - val_mean_absolute_percentage_error: 23.3840 - learning_rate: 0.0058
# Epoch 56/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3565.9397 - mean_absolute_percentage_error: 19.1232 - val_loss: 3583.9099 - val_mean_absolute_percentage_error: 22.3810 - learning_rate: 0.0058
# Epoch 57/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2637.8149 - mean_absolute_percentage_error: 18.6794 - val_loss: 3833.2976 - val_mean_absolute_percentage_error: 23.5791 - learning_rate: 0.0057
# Epoch 58/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2326.0317 - mean_absolute_percentage_error: 18.4799 - val_loss: 3839.2788 - val_mean_absolute_percentage_error: 23.3399 - learning_rate: 0.0057
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# MAPE by Warengruppe:
# Warengruppe 2: 15.12%
# Warengruppe 5: 17.60%
# Warengruppe 1: 20.61%
# Warengruppe 3: 21.00%
# Warengruppe 4: 24.13%
# Warengruppe 6: 47.06%
# /tmp/ipykernel_9652/3244241130.py:126: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mape_by_group = results_df.groupby('Warengruppe').apply(
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# MAPE on validation set: 20.51%
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# visualise the actual and predicted data

import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_train is your training dataframe and predicted_test.csv has the predictions
pred_df = pd.read_csv('predicted_test.csv')

# Plot each Warengruppe separately
unique_groups = df_train['Warengruppe'].unique()

# Set up the subplot grid
n_rows = (len(unique_groups) + 1) // 2
n_cols = min(2, len(unique_groups))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
axes = axes.flatten()

for idx, group in enumerate(unique_groups):
    # Filter data for current group
    actual_data = df_train[df_train['Warengruppe'] == group]
    pred_data = pred_df[pred_df['Warengruppe'] == group]
    
    # Plot actual values
    axes[idx].plot(pd.to_datetime(actual_data['Datum']), actual_data['Umsatz'], 
                  label='Actual', color='blue')
    
    # Continue with predicted values
    axes[idx].plot(pd.to_datetime(pred_data['Datum']), pred_data['Predicted_Umsatz'], 
                  label='Predicted', color='red')
    
    axes[idx].set_title(f'Warengruppe {group}')
    axes[idx].set_xlabel('Date')
    axes[idx].set_ylabel('Umsatz')
    axes[idx].legend()
    axes[idx].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('umsatz_prediction_plots.png')
plt.show()

# %%
# this code belongs up top, takes the data from X_train to make bar charts

import matplotlib.pyplot as plt
import numpy as np

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First plot: Weekdays
day_counts = []
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

for i in range(1, 8):  # 7 days
    day_counts.append(X_train[f'Day_{i}'].sum())  # sum() counts True values

# Plot weekdays
bars1 = ax1.bar(day_names, day_counts)
ax1.set_title('Number of Occurrences by Weekday')
ax1.set_xlabel('Weekday')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)

# Second plot: Months
month_counts = []
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

for i in range(1, 13):  # 12 months
    month_counts.append(X_train[f'Month_{i}'].sum())  # sum() counts True values

# Plot months
bars2 = ax2.bar(month_names, month_counts)
ax2.set_title('Number of Occurrences by Month')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 14
#      11 day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
#      13 for i in range(1, 8):  # 7 days
# ---> 14     day_counts.append(X_train[f'Day_{i}'].sum())  # sum() counts True values
#      16 # Plot weekdays
#      17 bars1 = ax1.bar(day_names, day_counts)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
