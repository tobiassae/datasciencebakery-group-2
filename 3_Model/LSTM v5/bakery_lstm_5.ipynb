# %%
'''

based on the 3.7 version

'''

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.metrics import MeanAbsolutePercentageError
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt

# Load data
kiwo_url = '../../Data/kiwo.csv'
umsatz_url = '../../Data/train.csv'
wetter_url = '../../Data/wetter.csv'
test_url = '../../Data/test.csv'

df_kiwo = pd.read_csv(kiwo_url)
df_umsatz = pd.read_csv(umsatz_url)
df_wetter = pd.read_csv(wetter_url)
df_test = pd.read_csv(test_url)

# Merge data
df_train = pd.merge(df_umsatz, df_wetter, on='Datum', how='left')
df_train = pd.merge(df_train, df_kiwo, on='Datum', how='left')
df_test = pd.merge(df_test, df_wetter, on='Datum', how='left')
df_test = pd.merge(df_test, df_kiwo, on='Datum', how='left')

# Function to prepare data
def prepare_data(data):
    data['Datum'] = pd.to_datetime(data['Datum'])
    data['DayOfWeek'] = data['Datum'].dt.dayofweek
    data['Month'] = data['Datum'].dt.month
    data['IsWeekend'] = (data['DayOfWeek'] >= 5).astype(float)
    data['KielerWoche'] = data['KielerWoche'].fillna(0).astype(float)
    
    # Replace NaNs using KNN Imputer
    numerical_cols = ['Temperatur', 'Windgeschwindigkeit', 'Bewoelkung', 'Wettercode', 'IsWeekend']
    knn_imputer = KNNImputer(n_neighbors=5)
    data[numerical_cols] = knn_imputer.fit_transform(data[numerical_cols])
    
    # One-hot encode categorical features
    warengruppe_dummies = pd.get_dummies(data['Warengruppe'], prefix='Warengruppe')
    day_dummies = pd.get_dummies(data['DayOfWeek'], prefix='Day')
    month_dummies = pd.get_dummies(data['Month'], prefix='Month')
    
    # Combine all features
    feature_df = pd.concat([data[numerical_cols], warengruppe_dummies, day_dummies, month_dummies], axis=1)
    return feature_df

# Prepare datasets
df_train_sorted = df_train.sort_values(by='Datum')
X_train = prepare_data(df_train_sorted)
y_train = df_train_sorted['Umsatz']
X_test = prepare_data(df_test)

print(X_train.head())

# Standardize data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# should be split on DATE? 
# Split data into training and validation sets
split_index = int(len(X_train) * 0.8)
X_train_seq, X_val_seq = X_train[:split_index], X_train[split_index:]
y_train_seq, y_val_seq = y_train[:split_index], y_train[split_index:]

# Reshape for LSTM (samples, time steps, features)
X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], 1, X_train_seq.shape[1])
X_val_seq = X_val_seq.reshape(X_val_seq.shape[0], 1, X_val_seq.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# Learning rate scheduler function
def lr_schedule(epoch, lr):
    initial_lr = 0.01  # Start with this learning rate
    decay_rate = 0.1  # Decay rate
    decay_steps = 10  # Epochs after which to decay
    return initial_lr * np.exp(-decay_rate * (epoch / decay_steps))

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

# Build the model 
model = tf.keras.Sequential([
    LSTM(64, activation='relu', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])), # default 50
    Dropout(0.2), # default 0.2
    Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse', metrics=['mean_absolute_percentage_error'])

# Train the model
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=50, # was 150
    batch_size=32, 
    validation_data=(X_val_seq, y_val_seq), 
    callbacks=[early_stopping, model_checkpoint, lr_scheduler]
)

# Calculate predictions for validation set
val_predictions = model.predict(X_val_seq).flatten()

# Get original Warengruppe values for validation set
val_warengruppen = df_train_sorted.iloc[split_index:]['Warengruppe']

# Create DataFrame with actual and predicted values
results_df = pd.DataFrame({
    'Warengruppe': val_warengruppen,
    'Actual': y_val_seq,
    'Predicted': val_predictions
})

# Calculate MAPE for each Warengruppe
mape_by_group = results_df.groupby('Warengruppe').apply(
    lambda x: MeanAbsolutePercentageError()(x['Actual'], x['Predicted']).numpy()
).sort_values()

# print("\nMAPE by Warengruppe:")

# save the MAPEs of each warengruppe in a dict
warengruppe_MAPE_dict = {}
for warengruppe, mape in mape_by_group.items():
    # print(f"Warengruppe {warengruppe}: {mape:.2f}%")
    warengruppe_MAPE_dict[warengruppe] = mape

fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the training and validation loss on the primary y-axis
ax1.plot(history.history['loss'], label='Train Loss', color='blue')
ax1.plot(history.history['val_loss'], label='Val Loss', color='darkblue')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')

# Determine the minimum and maximum loss values to set the y-axis limits
min_loss = min(min(history.history['loss']), min(history.history['val_loss']))
max_loss = max(max(history.history['loss']), max(history.history['val_loss']))
ax1.set_ylim(min_loss * 0.9, max_loss * 1.1)  # Add some padding
ax1.tick_params(axis='y', labelcolor='black')

# Create a twin y-axis for the MAPE
ax2 = ax1.twinx()

# Plot the training and validation MAPE on the twin y-axis
ax2.plot(history.history['mean_absolute_percentage_error'], label='Train MAPE', color='orange')
ax2.plot(history.history['val_mean_absolute_percentage_error'], label='Val MAPE', color='red')
ax2.set_ylabel('MAPE (%)', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Set the y-axis limits for the MAPE to 0-100%
ax2.set_ylim(0, 100)

# Add a legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# Load the best model
model.load_weights('best_model.keras')

# Evaluate on validation set
val_predictions = model.predict(X_val_seq).flatten()
val_mape = tf.keras.metrics.MeanAbsolutePercentageError()(y_val_seq, val_predictions).numpy()
print(f'MAPE on validation set: {val_mape:.2f}%')

# Make predictions on test set and save results
test_predictions = model.predict(X_test).flatten()
df_test['Predicted_Umsatz'] = test_predictions
df_test.to_csv('predicted_test.csv', index=False)
# Out:
#       Temperatur  Windgeschwindigkeit  Bewoelkung  Wettercode  IsWeekend  \
# 0        17.8375                 15.0         6.0        20.0        0.0
# 3638     17.8375                 15.0         6.0        20.0        0.0
# 7223     17.8375                 15.0         6.0        20.0        0.0
# 1819     17.8375                 15.0         6.0        20.0        0.0
# 5457     17.8375                 15.0         6.0        20.0        0.0
#
#       Warengruppe_1  Warengruppe_2  Warengruppe_3  Warengruppe_4  \
# 0              True          False          False          False
# 3638          False          False           True          False
# 7223          False          False          False          False
# 1819          False           True          False          False
# 5457          False          False          False           True
#
#       Warengruppe_5  ...  Month_3  Month_4  Month_5  Month_6  Month_7  \
# 0             False  ...    False    False    False    False     True
# 3638          False  ...    False    False    False    False     True
# 7223           True  ...    False    False    False    False     True
# 1819          False  ...    False    False    False    False     True
# 5457          False  ...    False    False    False    False     True
#
#       Month_8  Month_9  Month_10  Month_11  Month_12
# 0       False    False     False     False     False
# 3638    False    False     False     False     False
# 7223    False    False     False     False     False
# 1819    False    False     False     False     False
# 5457    False    False     False     False     False
#
# [5 rows x 30 columns]
# Epoch 1/50
# /home/codespace/.python/current/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 46227.7266 - mean_absolute_percentage_error: 76.2172 - val_loss: 3372.2131 - val_mean_absolute_percentage_error: 23.6934 - learning_rate: 0.0100
# Epoch 2/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4402.8882 - mean_absolute_percentage_error: 24.2981 - val_loss: 3085.9194 - val_mean_absolute_percentage_error: 21.7150 - learning_rate: 0.0099
# Epoch 3/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6069.1001 - mean_absolute_percentage_error: 22.3046 - val_loss: 3184.9177 - val_mean_absolute_percentage_error: 21.5925 - learning_rate: 0.0098
# Epoch 4/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4166.5234 - mean_absolute_percentage_error: 21.9095 - val_loss: 3075.7285 - val_mean_absolute_percentage_error: 21.1795 - learning_rate: 0.0097
# Epoch 5/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4341.7397 - mean_absolute_percentage_error: 21.3042 - val_loss: 3342.6458 - val_mean_absolute_percentage_error: 22.1656 - learning_rate: 0.0096
# Epoch 6/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5151.9097 - mean_absolute_percentage_error: 21.3144 - val_loss: 3345.3413 - val_mean_absolute_percentage_error: 22.4440 - learning_rate: 0.0095
# Epoch 7/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3882.0364 - mean_absolute_percentage_error: 20.6262 - val_loss: 3138.3655 - val_mean_absolute_percentage_error: 21.5269 - learning_rate: 0.0094
# Epoch 8/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3736.1250 - mean_absolute_percentage_error: 20.8909 - val_loss: 3734.2642 - val_mean_absolute_percentage_error: 23.4395 - learning_rate: 0.0093
# Epoch 9/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4285.3286 - mean_absolute_percentage_error: 20.8395 - val_loss: 3345.1313 - val_mean_absolute_percentage_error: 21.8223 - learning_rate: 0.0092
# Epoch 10/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4105.2002 - mean_absolute_percentage_error: 20.7600 - val_loss: 3289.7661 - val_mean_absolute_percentage_error: 22.5624 - learning_rate: 0.0091
# Epoch 11/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3249.1921 - mean_absolute_percentage_error: 20.6768 - val_loss: 3160.1489 - val_mean_absolute_percentage_error: 22.0666 - learning_rate: 0.0090
# Epoch 12/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3274.6050 - mean_absolute_percentage_error: 20.9328 - val_loss: 3479.2344 - val_mean_absolute_percentage_error: 22.8629 - learning_rate: 0.0090
# Epoch 13/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3598.0085 - mean_absolute_percentage_error: 20.6360 - val_loss: 3371.6226 - val_mean_absolute_percentage_error: 22.4304 - learning_rate: 0.0089
# Epoch 14/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4282.2949 - mean_absolute_percentage_error: 20.3258 - val_loss: 3436.5586 - val_mean_absolute_percentage_error: 22.3908 - learning_rate: 0.0088
# Epoch 15/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3615.6228 - mean_absolute_percentage_error: 20.6714 - val_loss: 3222.5923 - val_mean_absolute_percentage_error: 21.7221 - learning_rate: 0.0087
# Epoch 16/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4240.6558 - mean_absolute_percentage_error: 20.9971 - val_loss: 3494.5024 - val_mean_absolute_percentage_error: 22.8906 - learning_rate: 0.0086
# Epoch 17/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4110.6201 - mean_absolute_percentage_error: 20.5657 - val_loss: 3296.7256 - val_mean_absolute_percentage_error: 22.1344 - learning_rate: 0.0085
# Epoch 18/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2728.9358 - mean_absolute_percentage_error: 20.0710 - val_loss: 3557.9817 - val_mean_absolute_percentage_error: 23.1014 - learning_rate: 0.0084
# Epoch 19/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2660.7151 - mean_absolute_percentage_error: 19.8194 - val_loss: 3585.9592 - val_mean_absolute_percentage_error: 23.6092 - learning_rate: 0.0084
# Epoch 20/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3620.8386 - mean_absolute_percentage_error: 20.8492 - val_loss: 3258.3694 - val_mean_absolute_percentage_error: 21.8263 - learning_rate: 0.0083
# Epoch 21/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3452.8679 - mean_absolute_percentage_error: 20.2971 - val_loss: 3221.5283 - val_mean_absolute_percentage_error: 21.8758 - learning_rate: 0.0082
# Epoch 22/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3015.1082 - mean_absolute_percentage_error: 19.9582 - val_loss: 3221.5002 - val_mean_absolute_percentage_error: 21.6848 - learning_rate: 0.0081
# Epoch 23/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4415.9927 - mean_absolute_percentage_error: 20.3317 - val_loss: 3366.2976 - val_mean_absolute_percentage_error: 22.2814 - learning_rate: 0.0080
# Epoch 24/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3878.4204 - mean_absolute_percentage_error: 19.7772 - val_loss: 3402.7949 - val_mean_absolute_percentage_error: 22.4120 - learning_rate: 0.0079
# Epoch 25/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3490.4028 - mean_absolute_percentage_error: 19.9325 - val_loss: 3647.0200 - val_mean_absolute_percentage_error: 23.5395 - learning_rate: 0.0079
# Epoch 26/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3449.2119 - mean_absolute_percentage_error: 19.3998 - val_loss: 3377.7510 - val_mean_absolute_percentage_error: 22.1011 - learning_rate: 0.0078
# Epoch 27/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3476.4133 - mean_absolute_percentage_error: 19.2404 - val_loss: 3402.4658 - val_mean_absolute_percentage_error: 22.6859 - learning_rate: 0.0077
# Epoch 28/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3635.4712 - mean_absolute_percentage_error: 19.6131 - val_loss: 3324.1526 - val_mean_absolute_percentage_error: 22.1517 - learning_rate: 0.0076
# Epoch 29/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2724.6116 - mean_absolute_percentage_error: 19.6128 - val_loss: 3482.3335 - val_mean_absolute_percentage_error: 22.8891 - learning_rate: 0.0076
# Epoch 30/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3785.6289 - mean_absolute_percentage_error: 19.8377 - val_loss: 3567.8672 - val_mean_absolute_percentage_error: 23.0740 - learning_rate: 0.0075
# Epoch 31/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4596.9077 - mean_absolute_percentage_error: 20.0946 - val_loss: 3460.3008 - val_mean_absolute_percentage_error: 22.7005 - learning_rate: 0.0074
# Epoch 32/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4082.3662 - mean_absolute_percentage_error: 19.6001 - val_loss: 3517.9548 - val_mean_absolute_percentage_error: 23.2226 - learning_rate: 0.0073
# Epoch 33/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3651.8311 - mean_absolute_percentage_error: 19.5747 - val_loss: 3508.9963 - val_mean_absolute_percentage_error: 22.7951 - learning_rate: 0.0073
# Epoch 34/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2907.3999 - mean_absolute_percentage_error: 19.2445 - val_loss: 3517.4348 - val_mean_absolute_percentage_error: 22.8770 - learning_rate: 0.0072
# Epoch 35/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3581.9038 - mean_absolute_percentage_error: 19.5141 - val_loss: 3454.7173 - val_mean_absolute_percentage_error: 22.5967 - learning_rate: 0.0071
# Epoch 36/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3312.8245 - mean_absolute_percentage_error: 19.6263 - val_loss: 3630.5093 - val_mean_absolute_percentage_error: 23.3259 - learning_rate: 0.0070
# Epoch 37/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3810.1592 - mean_absolute_percentage_error: 19.9897 - val_loss: 3445.4592 - val_mean_absolute_percentage_error: 22.3043 - learning_rate: 0.0070
# Epoch 38/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4332.1631 - mean_absolute_percentage_error: 19.4919 - val_loss: 3782.5137 - val_mean_absolute_percentage_error: 23.4581 - learning_rate: 0.0069
# Epoch 39/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2668.4937 - mean_absolute_percentage_error: 19.3840 - val_loss: 3667.3564 - val_mean_absolute_percentage_error: 23.5258 - learning_rate: 0.0068
# Epoch 40/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3542.9119 - mean_absolute_percentage_error: 19.5996 - val_loss: 3463.9199 - val_mean_absolute_percentage_error: 22.5127 - learning_rate: 0.0068
# Epoch 41/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3559.9409 - mean_absolute_percentage_error: 19.4139 - val_loss: 3783.7874 - val_mean_absolute_percentage_error: 23.7976 - learning_rate: 0.0067
# Epoch 42/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2614.0647 - mean_absolute_percentage_error: 19.2761 - val_loss: 3757.4136 - val_mean_absolute_percentage_error: 23.4428 - learning_rate: 0.0066
# Epoch 43/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2660.7183 - mean_absolute_percentage_error: 18.9520 - val_loss: 3938.8691 - val_mean_absolute_percentage_error: 24.0928 - learning_rate: 0.0066
# Epoch 44/50
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3240.5745 - mean_absolute_percentage_error: 19.5981 - val_loss: 3508.9438 - val_mean_absolute_percentage_error: 22.4163 - learning_rate: 0.0065
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /tmp/ipykernel_7031/3567523653.py:126: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mape_by_group = results_df.groupby('Warengruppe').apply(

# %%
# visualise the actual and predicted data

import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_train is your training dataframe and predicted_test.csv has the predictions
pred_df = pd.read_csv('predicted_test.csv')

# Plot each Warengruppe separately
unique_groups = df_train['Warengruppe'].unique()

# Set up the subplot grid
n_rows = (len(unique_groups) + 1) // 2
n_cols = min(2, len(unique_groups))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
axes = axes.flatten()

for idx, group in enumerate(unique_groups):
    # Filter data for current group
    actual_data = df_train[df_train['Warengruppe'] == group]
    pred_data = pred_df[pred_df['Warengruppe'] == group]
    
    # Plot actual values
    axes[idx].plot(pd.to_datetime(actual_data['Datum']), actual_data['Umsatz'], 
                  label='Actual', color='blue')
    
    # Continue with predicted values
    axes[idx].plot(pd.to_datetime(pred_data['Datum']), pred_data['Predicted_Umsatz'], 
                  label='Predicted', color='red')
    
    axes[idx].set_title(f'Warengruppe {group}')
    axes[idx].set_xlabel('Date')
    axes[idx].set_ylabel('Umsatz')
    axes[idx].legend()
    axes[idx].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('umsatz_prediction_plots.png')
plt.show()

# %%
# this code belongs up top, takes the data from X_train to make bar charts

import matplotlib.pyplot as plt
import numpy as np

# Create figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First plot: Weekdays
day_counts = []
day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

for i in range(1, 8):  # 7 days
    day_counts.append(X_train[f'Day_{i}'].sum())  # sum() counts True values

# Plot weekdays
bars1 = ax1.bar(day_names, day_counts)
ax1.set_title('Number of Occurrences by Weekday')
ax1.set_xlabel('Weekday')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)

# Second plot: Months
month_counts = []
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

for i in range(1, 13):  # 12 months
    month_counts.append(X_train[f'Month_{i}'].sum())  # sum() counts True values

# Plot months
bars2 = ax2.bar(month_names, month_counts)
ax2.set_title('Number of Occurrences by Month')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 14
#      11 day_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
#      13 for i in range(1, 8):  # 7 days
# ---> 14     day_counts.append(X_train[f'Day_{i}'].sum())  # sum() counts True values
#      16 # Plot weekdays
#      17 bars1 = ax1.bar(day_names, day_counts)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
