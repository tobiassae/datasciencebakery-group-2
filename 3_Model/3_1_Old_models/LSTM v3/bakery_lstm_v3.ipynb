# %%
import pandas as pd
import numpy as np
from numpy import typing
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load data
kiwo_url = '../../Data/kiwo.csv'
umsatz_url = '../../Data/train.csv'
wetter_url = '../../Data/wetter.csv'
test_url = '../../Data/test.csv'

df_kiwo = pd.read_csv(kiwo_url)
df_umsatz = pd.read_csv(umsatz_url)
df_wetter = pd.read_csv(wetter_url)
df_test = pd.read_csv(test_url)

# Merge data
df_train = pd.merge(df_umsatz, df_wetter, on='Datum', how='left')
df_train = pd.merge(df_train, df_kiwo, on='Datum', how='left')
df_test = pd.merge(df_test, df_wetter, on='Datum', how='left')
df_test = pd.merge(df_test, df_kiwo, on='Datum', how='left')

def prepare_data(data):
    data['Datum'] = pd.to_datetime(data['Datum'])
    
    # One-hot encode day and month
    data['DayOfWeek'] = data['Datum'].dt.dayofweek
    data['Month'] = data['Datum'].dt.month
    day_dummies = pd.get_dummies(data['DayOfWeek'], prefix='Day')
    month_dummies = pd.get_dummies(data['Month'], prefix='Month')
    
    # Basic features
    data['IsWeekend'] = (data['DayOfWeek'] >= 5).astype(float)
    data['KielerWoche'] = data['KielerWoche'].fillna(0).astype(float)
    data['Temperatur'] = data['Temperatur'].fillna(data['Temperatur'].mean())
    data['Windgeschwindigkeit'] = data['Windgeschwindigkeit'].fillna(data['Windgeschwindigkeit'].mean())
    
    numerical_cols = ['Temperatur', 'Windgeschwindigkeit', 'IsWeekend', 'KielerWoche']
    feature_df = pd.concat([day_dummies, month_dummies, data[numerical_cols]], axis=1)
    
    return feature_df

# Prepare datasets
X_train = prepare_data(df_train)
y_train = df_train['Umsatz']
X_test = prepare_data(df_test)

# Split data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Standardize numerical features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Reshape data for LSTM layer (samples, timesteps, features)
timesteps = 1  # Since we are predicting based on single timestep data
X_train = X_train.reshape((X_train.shape[0], timesteps, X_train.shape[1]))
X_val = X_val.reshape((X_val.shape[0], timesteps, X_val.shape[1]))
X_test = X_test.reshape((X_test.shape[0], timesteps, X_test.shape[1]))

# Define custom MAPE metric
def mean_absolute_percentage_error(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    diff = tf.abs((y_true - y_pred) / tf.clip_by_value(tf.abs(y_true), 1e-8, tf.float32.max))
    return 100. * tf.reduce_mean(diff)

# Build LSTM model
model = tf.keras.Sequential([
    LSTM(50, activation='relu', input_shape=(timesteps, X_train.shape[2])),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=[mean_absolute_percentage_error])

# Define early stopping and model checkpoint
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), 
                    callbacks=[early_stopping, model_checkpoint])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.plot(history.history['mean_absolute_percentage_error'], label='train_mape')
plt.plot(history.history['val_mean_absolute_percentage_error'], label='val_mape')
plt.xlabel('Epoch')
plt.ylabel('Loss/Metric')
plt.legend()
plt.show()

# Load the best model
model.load_weights('best_model.keras')

# Make predictions on the test set
test_predictions = model.predict(X_test)

# Add predictions to the test dataframe
df_test['Predicted_Umsatz'] = test_predictions

# Save the test dataframe with predictions
df_test.to_csv('predicted_test.csv', index=False)

# Evaluate the model on validation set
val_predictions = model.predict(X_val)
val_mape = mean_absolute_percentage_error(y_val, val_predictions)
print(f'MAPE on validation set: {val_mape:.2f}%')
# Out:
# Epoch 1/150
# /home/codespace/.python/current/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 43881.8008 - mean_absolute_percentage_error: 77.0846 - val_loss: 2879.4624 - val_mean_absolute_percentage_error: 24.6885 - learning_rate: 0.0100
# Epoch 2/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5256.7603 - mean_absolute_percentage_error: 25.4134 - val_loss: 2273.1306 - val_mean_absolute_percentage_error: 20.8494 - learning_rate: 0.0099
# Epoch 3/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5185.8022 - mean_absolute_percentage_error: 24.1396 - val_loss: 2209.7595 - val_mean_absolute_percentage_error: 19.8461 - learning_rate: 0.0098
# Epoch 4/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5011.2671 - mean_absolute_percentage_error: 22.4788 - val_loss: 2101.2732 - val_mean_absolute_percentage_error: 19.7057 - learning_rate: 0.0097
# Epoch 5/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4987.2031 - mean_absolute_percentage_error: 21.8648 - val_loss: 2120.0049 - val_mean_absolute_percentage_error: 19.5918 - learning_rate: 0.0096
# Epoch 6/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4803.7983 - mean_absolute_percentage_error: 21.5622 - val_loss: 2277.4539 - val_mean_absolute_percentage_error: 21.2710 - learning_rate: 0.0095
# Epoch 7/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4556.2490 - mean_absolute_percentage_error: 22.1552 - val_loss: 2250.6987 - val_mean_absolute_percentage_error: 20.3495 - learning_rate: 0.0094
# Epoch 8/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3953.0300 - mean_absolute_percentage_error: 21.2265 - val_loss: 2170.2937 - val_mean_absolute_percentage_error: 20.1971 - learning_rate: 0.0093
# Epoch 9/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4323.8115 - mean_absolute_percentage_error: 21.3462 - val_loss: 2069.4138 - val_mean_absolute_percentage_error: 19.2706 - learning_rate: 0.0092
# Epoch 10/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5337.5879 - mean_absolute_percentage_error: 21.3303 - val_loss: 2114.3594 - val_mean_absolute_percentage_error: 19.4435 - learning_rate: 0.0091
# Epoch 11/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3289.1526 - mean_absolute_percentage_error: 20.9991 - val_loss: 2125.4241 - val_mean_absolute_percentage_error: 20.1000 - learning_rate: 0.0090
# Epoch 12/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4281.7388 - mean_absolute_percentage_error: 21.3701 - val_loss: 2151.8076 - val_mean_absolute_percentage_error: 19.3552 - learning_rate: 0.0090
# Epoch 13/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5067.9653 - mean_absolute_percentage_error: 21.6484 - val_loss: 2100.9065 - val_mean_absolute_percentage_error: 19.6004 - learning_rate: 0.0089
# Epoch 14/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4281.0977 - mean_absolute_percentage_error: 20.8992 - val_loss: 2117.0242 - val_mean_absolute_percentage_error: 19.3887 - learning_rate: 0.0088
# Epoch 15/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5009.0317 - mean_absolute_percentage_error: 21.0611 - val_loss: 2110.7356 - val_mean_absolute_percentage_error: 19.0527 - learning_rate: 0.0087
# Epoch 16/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3871.2141 - mean_absolute_percentage_error: 20.7132 - val_loss: 2205.6577 - val_mean_absolute_percentage_error: 20.2571 - learning_rate: 0.0086
# Epoch 17/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3812.1824 - mean_absolute_percentage_error: 20.2981 - val_loss: 2163.6167 - val_mean_absolute_percentage_error: 19.6837 - learning_rate: 0.0085
# Epoch 18/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4345.9927 - mean_absolute_percentage_error: 20.9032 - val_loss: 2140.1790 - val_mean_absolute_percentage_error: 19.5658 - learning_rate: 0.0084
# Epoch 19/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4052.7832 - mean_absolute_percentage_error: 20.7880 - val_loss: 2110.0610 - val_mean_absolute_percentage_error: 19.4192 - learning_rate: 0.0084
# Epoch 20/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3635.1191 - mean_absolute_percentage_error: 20.7731 - val_loss: 2115.3257 - val_mean_absolute_percentage_error: 19.5322 - learning_rate: 0.0083
# Epoch 21/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4115.1436 - mean_absolute_percentage_error: 20.3981 - val_loss: 2108.2563 - val_mean_absolute_percentage_error: 19.4530 - learning_rate: 0.0082
# Epoch 22/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3520.6545 - mean_absolute_percentage_error: 20.4343 - val_loss: 2216.9873 - val_mean_absolute_percentage_error: 20.5378 - learning_rate: 0.0081
# Epoch 23/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3633.0352 - mean_absolute_percentage_error: 20.5319 - val_loss: 2227.2139 - val_mean_absolute_percentage_error: 20.3152 - learning_rate: 0.0080
# Epoch 24/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3341.8479 - mean_absolute_percentage_error: 20.2724 - val_loss: 2146.5281 - val_mean_absolute_percentage_error: 19.7356 - learning_rate: 0.0079
# Epoch 25/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3235.6602 - mean_absolute_percentage_error: 20.0537 - val_loss: 2140.6013 - val_mean_absolute_percentage_error: 19.6871 - learning_rate: 0.0079
# Epoch 26/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4496.7866 - mean_absolute_percentage_error: 20.5720 - val_loss: 2103.5793 - val_mean_absolute_percentage_error: 19.3599 - learning_rate: 0.0078
# Epoch 27/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3643.2510 - mean_absolute_percentage_error: 20.1686 - val_loss: 2234.4473 - val_mean_absolute_percentage_error: 20.2627 - learning_rate: 0.0077
# Epoch 28/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4474.7788 - mean_absolute_percentage_error: 20.2878 - val_loss: 2141.5781 - val_mean_absolute_percentage_error: 19.2872 - learning_rate: 0.0076
# Epoch 29/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3448.9407 - mean_absolute_percentage_error: 20.2763 - val_loss: 2186.3000 - val_mean_absolute_percentage_error: 19.7277 - learning_rate: 0.0076
# Epoch 30/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4140.9844 - mean_absolute_percentage_error: 20.4732 - val_loss: 2208.2620 - val_mean_absolute_percentage_error: 19.6713 - learning_rate: 0.0075
# Epoch 31/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3319.6763 - mean_absolute_percentage_error: 19.9796 - val_loss: 2168.0874 - val_mean_absolute_percentage_error: 19.5203 - learning_rate: 0.0074
# Epoch 32/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3539.1543 - mean_absolute_percentage_error: 20.0410 - val_loss: 2207.0669 - val_mean_absolute_percentage_error: 20.0145 - learning_rate: 0.0073
# Epoch 33/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3777.6111 - mean_absolute_percentage_error: 20.1388 - val_loss: 2185.8469 - val_mean_absolute_percentage_error: 19.5005 - learning_rate: 0.0073
# Epoch 34/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3314.3728 - mean_absolute_percentage_error: 19.6826 - val_loss: 2223.8601 - val_mean_absolute_percentage_error: 20.1339 - learning_rate: 0.0072
# Epoch 35/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3606.2913 - mean_absolute_percentage_error: 20.0583 - val_loss: 2163.5469 - val_mean_absolute_percentage_error: 19.5464 - learning_rate: 0.0071
# Epoch 36/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3539.6335 - mean_absolute_percentage_error: 19.8499 - val_loss: 2226.4321 - val_mean_absolute_percentage_error: 20.0665 - learning_rate: 0.0070
# Epoch 37/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3224.9812 - mean_absolute_percentage_error: 20.3672 - val_loss: 2223.2917 - val_mean_absolute_percentage_error: 20.1993 - learning_rate: 0.0070
# Epoch 38/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3699.3794 - mean_absolute_percentage_error: 20.0269 - val_loss: 2177.5469 - val_mean_absolute_percentage_error: 19.4562 - learning_rate: 0.0069
# Epoch 39/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3178.6436 - mean_absolute_percentage_error: 19.7112 - val_loss: 2222.8501 - val_mean_absolute_percentage_error: 19.9945 - learning_rate: 0.0068
# Epoch 40/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3133.5820 - mean_absolute_percentage_error: 19.9823 - val_loss: 2252.0186 - val_mean_absolute_percentage_error: 20.3457 - learning_rate: 0.0068
# Epoch 41/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3851.3445 - mean_absolute_percentage_error: 19.9796 - val_loss: 2200.8943 - val_mean_absolute_percentage_error: 19.8857 - learning_rate: 0.0067
# Epoch 42/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3390.5317 - mean_absolute_percentage_error: 20.0817 - val_loss: 2238.3696 - val_mean_absolute_percentage_error: 19.8443 - learning_rate: 0.0066
# Epoch 43/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3906.4443 - mean_absolute_percentage_error: 19.9242 - val_loss: 2196.5029 - val_mean_absolute_percentage_error: 19.4324 - learning_rate: 0.0066
# Epoch 44/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3396.9556 - mean_absolute_percentage_error: 19.7342 - val_loss: 2233.9822 - val_mean_absolute_percentage_error: 19.3243 - learning_rate: 0.0065
# Epoch 45/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3892.0298 - mean_absolute_percentage_error: 20.0534 - val_loss: 2237.8252 - val_mean_absolute_percentage_error: 19.9675 - learning_rate: 0.0064
# Epoch 46/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2781.0710 - mean_absolute_percentage_error: 19.2738 - val_loss: 2336.6631 - val_mean_absolute_percentage_error: 20.7320 - learning_rate: 0.0064
# Epoch 47/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3695.6948 - mean_absolute_percentage_error: 20.0945 - val_loss: 2202.6516 - val_mean_absolute_percentage_error: 19.9280 - learning_rate: 0.0063
# Epoch 48/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3177.5647 - mean_absolute_percentage_error: 19.1969 - val_loss: 2276.9087 - val_mean_absolute_percentage_error: 19.5882 - learning_rate: 0.0063
# Epoch 49/150
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2766.7986 - mean_absolute_percentage_error: 19.3038 - val_loss: 2394.5684 - val_mean_absolute_percentage_error: 20.4626 - learning_rate: 0.0062
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MAPE on validation set: 19.27%
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
